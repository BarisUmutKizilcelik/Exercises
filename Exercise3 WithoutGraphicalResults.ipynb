# %%
# %pip install edge-ml
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting edge-ml
#   Downloading edge_ml-0.3.3-py3-none-any.whl.metadata (6.7 kB)
# Downloading edge_ml-0.3.3-py3-none-any.whl (7.6 kB)
# Installing collected packages: edge-ml
# Successfully installed edge-ml-0.3.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
from edgeml import DatasetReceiver
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFECV

# %%
# Load the dataset using DatasetReceiver
project=DatasetReceiver("https://beta.edge-ml.org","6b110fec3d9b24ab616f9cd1fde80fa7")
project.loadData()

# %%
# Save the loaded project to a pickle file
pickle.dump(project, open("../exercises/project.pkl","wb"))
print("DONE DUMPING")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Save the loaded project to a pickle file
# ----> 2 pickle.dump(project, open("../exercises/project.pkl","wb"))
#       3 print("DONE DUMPING")
#
# NameError: name 'project' is not defined

# %%
# Load the project from the pickle file
project=pickle.load(open("../exercises/project.pkl","rb"))
print("DONE LOADING")
# Out:
# DONE LOADING

# %%
# Concatenate the datasets into a single dataframe
concanated_data=pd.concat([d.data.iloc[40:-40].dropna().assign(**d.metaData) for d  in project.datasets if (d.name == "devicemotion" and d.data.shape[0]>0) and d.timeSeries[0].end-d.timeSeries[0].start>10000] )
concanated_data
# Out:
#                       time  acceleration.x  acceleration.y  acceleration.z  \
# 40 2024-05-04 06:37:51.934            -0.3            -0.7            -2.6
# 41 2024-05-04 06:37:51.950            -0.2            -0.2            -3.0
# 42 2024-05-04 06:37:51.967             0.3             0.3            -2.7
# 43 2024-05-04 06:37:51.984             0.5             0.2            -1.0
# 44 2024-05-04 06:37:52.001             0.5             0.2            -1.0
# ..                     ...             ...             ...             ...
# 84 2024-05-07 12:03:57.696             0.1             0.0             0.1
# 85 2024-05-07 12:03:57.712             0.1             0.0             0.1
# 86 2024-05-07 12:03:57.729             0.0             0.0             0.0
# 87 2024-05-07 12:03:57.746             0.0             0.0             0.0
# 88 2024-05-07 12:03:57.762             0.0             0.0             0.0
#
#     accelerationIncludingGravity.x  accelerationIncludingGravity.y  \
# 40                            -0.5                             4.0
# 41                            -0.1                             4.3
# 42                             0.1                             4.3
# 43                             0.1                             4.3
# 44                            -0.1                             4.4
# ..                             ...                             ...
# 84                             0.3                             4.8
# 85                             0.3                             4.8
# 86                             0.3                             4.8
# 87                             0.3                             4.7
# 88                             0.2                             4.7
#
#     accelerationIncludingGravity.z  rotationRate.alpha  rotationRate.beta  \
# 40                             6.3                12.5                7.5
# 41                             6.7                 9.6               -0.1
# 42                             8.2                12.7               -4.5
# 43                             8.1                25.4                1.8
# 44                             8.0                25.4                1.8
# ..                             ...                 ...                ...
# 84                             8.6                -3.3                3.5
# 85                             8.6                -0.8                1.3
# 86                             8.6                 0.4               -1.3
# 87                             8.5                 0.2               -1.9
# 88                             8.5                -1.0               -0.4
#
#     rotationRate.gamma participantId activity        mobile browser
# 40           41.599998         111f7  testing  UnknownPhone  Chrome
# 41           36.099998         111f7  testing  UnknownPhone  Chrome
# 42           28.400000         111f7  testing  UnknownPhone  Chrome
# 43           13.600000         111f7  testing  UnknownPhone  Chrome
# 44           13.600000         111f7  testing  UnknownPhone  Chrome
# ..                 ...           ...      ...           ...     ...
# 84           -2.000000         uksco  sitting  UnknownPhone  Chrome
# 85           -1.400000         uksco  sitting  UnknownPhone  Chrome
# 86           -0.900000         uksco  sitting  UnknownPhone  Chrome
# 87           -0.800000         uksco  sitting  UnknownPhone  Chrome
# 88           -1.400000         uksco  sitting  UnknownPhone  Chrome
#
# [126370 rows x 14 columns]

# %%
# Filter out rows where activity is "testing"
filtered_data=concanated_data[concanated_data.activity!="testing"]

# Drop "mobile" and "browser" columns and convert "browser" to dummy variables
filtered_data=pd.concat([filtered_data.drop(columns=["mobile","browser"]),pd.get_dummies(filtered_data[["browser"]])], axis=1)

# Set the index to "time" and drop the "time" column
filtered_data.index=filtered_data.time
filtered_data=filtered_data.drop(columns="time")

# Factorize the "activity" column and store the labels
filtered_data["activity"],labels=filtered_data["activity"].factorize()
filtered_data
# Out:
#                          acceleration.x  acceleration.y  acceleration.z  \
# time
# 2024-05-04 06:39:09.013            -7.1             3.5             2.4
# 2024-05-04 06:39:09.030            -7.9             2.7             4.1
# 2024-05-04 06:39:09.046            -8.6             2.0             4.3
# 2024-05-04 06:39:09.063            -9.4             2.0             2.0
# 2024-05-04 06:39:09.080            -9.4             2.0             2.0
# ...                                 ...             ...             ...
# 2024-05-07 12:03:57.696             0.1             0.0             0.1
# 2024-05-07 12:03:57.712             0.1             0.0             0.1
# 2024-05-07 12:03:57.729             0.0             0.0             0.0
# 2024-05-07 12:03:57.746             0.0             0.0             0.0
# 2024-05-07 12:03:57.762             0.0             0.0             0.0
#
#                          accelerationIncludingGravity.x  \
# time
# 2024-05-04 06:39:09.013                            -0.5
# 2024-05-04 06:39:09.030                            -1.3
# 2024-05-04 06:39:09.046                            -1.7
# 2024-05-04 06:39:09.063                            -2.8
# 2024-05-04 06:39:09.080                            -2.8
# ...                                                 ...
# 2024-05-07 12:03:57.696                             0.3
# 2024-05-07 12:03:57.712                             0.3
# 2024-05-07 12:03:57.729                             0.3
# 2024-05-07 12:03:57.746                             0.3
# 2024-05-07 12:03:57.762                             0.2
#
#                          accelerationIncludingGravity.y  \
# time
# 2024-05-04 06:39:09.013                            -3.8
# 2024-05-04 06:39:09.030                            -4.5
# 2024-05-04 06:39:09.046                            -4.7
# 2024-05-04 06:39:09.063                            -5.0
# 2024-05-04 06:39:09.080                            -5.0
# ...                                                 ...
# 2024-05-07 12:03:57.696                             4.8
# 2024-05-07 12:03:57.712                             4.8
# 2024-05-07 12:03:57.729                             4.8
# 2024-05-07 12:03:57.746                             4.7
# 2024-05-07 12:03:57.762                             4.7
#
#                          accelerationIncludingGravity.z  rotationRate.alpha  \
# time
# 2024-05-04 06:39:09.013                             3.0           55.900002
# 2024-05-04 06:39:09.030                             3.8           69.099998
# 2024-05-04 06:39:09.046                             3.2           59.000000
# 2024-05-04 06:39:09.063                             1.5           48.700001
# 2024-05-04 06:39:09.080                             1.5           43.599998
# ...                                                 ...                 ...
# 2024-05-07 12:03:57.696                             8.6           -3.300000
# 2024-05-07 12:03:57.712                             8.6           -0.800000
# 2024-05-07 12:03:57.729                             8.6            0.400000
# 2024-05-07 12:03:57.746                             8.5            0.200000
# 2024-05-07 12:03:57.762                             8.5           -1.000000
#
#                          rotationRate.beta  rotationRate.gamma participantId  \
# time
# 2024-05-04 06:39:09.013        -128.300003          -27.900000         12417
# 2024-05-04 06:39:09.030         -55.400002            0.500000         12417
# 2024-05-04 06:39:09.046          -8.300000           20.500000         12417
# 2024-05-04 06:39:09.063          15.600000           45.200001         12417
# 2024-05-04 06:39:09.080          24.799999           75.099998         12417
# ...                                    ...                 ...           ...
# 2024-05-07 12:03:57.696           3.500000           -2.000000         uksco
# 2024-05-07 12:03:57.712           1.300000           -1.400000         uksco
# 2024-05-07 12:03:57.729          -1.300000           -0.900000         uksco
# 2024-05-07 12:03:57.746          -1.900000           -0.800000         uksco
# 2024-05-07 12:03:57.762          -0.400000           -1.400000         uksco
#
#                          activity  browser_Chrome  browser_Firefox
# time
# 2024-05-04 06:39:09.013         0           False            False
# 2024-05-04 06:39:09.030         0           False            False
# 2024-05-04 06:39:09.046         0           False            False
# 2024-05-04 06:39:09.063         0           False            False
# 2024-05-04 06:39:09.080         0           False            False
# ...                           ...             ...              ...
# 2024-05-07 12:03:57.696         2            True            False
# 2024-05-07 12:03:57.712         2            True            False
# 2024-05-07 12:03:57.729         2            True            False
# 2024-05-07 12:03:57.746         2            True            False
# 2024-05-07 12:03:57.762         2            True            False
#
# [121803 rows x 13 columns]

# %%
# Define a function to compute the mode
def mode(x): 
    return (x.mode()[0])

# Define aggregation functions for different column
aggs={ **dict.fromkeys(filtered_data.select_dtypes(exclude=[np.float32]).columns, [ lambda x : x.mode()[0]  ]),
      **dict.fromkeys(filtered_data.select_dtypes(include=[np.float32]).columns, ["mean","var","min","max","median"])}
del(aggs["participantId"])

# %%
# Apply rolling window aggregation grouped by "participantId"
windowed_data=filtered_data.groupby("participantId").rolling("1s").agg(aggs)
windowed_data.columns = [col[0] + "." + col[1] if col [1] != "<lambda>" else col[0] for col in windowed_data.columns]
windowed_data

# %%
# Prepare the dataframe for modeling
windowed_data_copy=windowed_data.copy()
windowed_data_copy.index=windowed_data.index.droplevel(1)
windowed_data_copy=windowed_data_copy.reset_index()
windowed_data_copy.dropna(inplace=True)
windowed_data_copy
# Out:
#        participantId  activity  browser_Chrome  browser_Firefox  \
# 1              10280       2.0             0.0              1.0
# 2              10280       2.0             0.0              1.0
# 3              10280       2.0             0.0              1.0
# 4              10280       2.0             0.0              1.0
# 5              10280       2.0             0.0              1.0
# ...              ...       ...             ...              ...
# 121798         uksco       2.0             1.0              0.0
# 121799         uksco       2.0             1.0              0.0
# 121800         uksco       2.0             1.0              0.0
# 121801         uksco       2.0             1.0              0.0
# 121802         uksco       2.0             1.0              0.0
#
#         acceleration.x.mean  acceleration.x.var  acceleration.x.min  \
# 1                  0.000000            0.000000                 0.0
# 2                  0.000000            0.000000                 0.0
# 3                  0.000000            0.000000                 0.0
# 4                  0.000000            0.000000                 0.0
# 5                  0.000000            0.000000                 0.0
# ...                     ...                 ...                 ...
# 121798            -0.020000            0.008909                -0.2
# 121799            -0.017391            0.009024                -0.2
# 121800            -0.017021            0.008834                -0.2
# 121801            -0.016667            0.008652                -0.2
# 121802            -0.016327            0.008478                -0.2
#
#         acceleration.x.max  acceleration.x.median  acceleration.y.mean  ...  \
# 1                      0.0                    0.0             0.020000  ...
# 2                      0.0                    0.0             0.020000  ...
# 3                      0.0                    0.0             0.020000  ...
# 4                      0.0                    0.0             0.020000  ...
# 5                      0.0                    0.0             0.020000  ...
# ...                    ...                    ...                  ...  ...
# 121798                 0.1                    0.0            -0.006667  ...
# 121799                 0.1                    0.0            -0.006522  ...
# 121800                 0.1                    0.0            -0.006383  ...
# 121801                 0.1                    0.0            -0.006250  ...
# 121802                 0.1                    0.0            -0.006122  ...
#
#         rotationRate.beta.mean  rotationRate.beta.var  rotationRate.beta.min  \
# 1                    -0.030000               0.000000                  -0.03
# 2                    -0.030000               0.000000                  -0.03
# 3                    -0.030000               0.000000                  -0.03
# 4                    -0.030000               0.000000                  -0.03
# 5                    -0.030000               0.000000                  -0.03
# ...                        ...                    ...                    ...
# 121798                0.900000              15.907273                  -9.80
# 121799                0.908696              15.557256                  -9.80
# 121800                0.861702              15.322850                  -9.80
# 121801                0.804167              15.155727                  -9.80
# 121802                0.779592              14.869575                  -9.80
#
#         rotationRate.beta.max  rotationRate.beta.median  \
# 1                       -0.03                     -0.03
# 2                       -0.03                     -0.03
# 3                       -0.03                     -0.03
# 4                       -0.03                     -0.03
# 5                       -0.03                     -0.03
# ...                       ...                       ...
# 121798                   9.00                      1.10
# 121799                   9.00                      1.10
# 121800                   9.00                      1.10
# 121801                   9.00                      0.95
# 121802                   9.00                      0.80
#
#         rotationRate.gamma.mean  rotationRate.gamma.var  \
# 1                     -0.060000                0.000000
# 2                     -0.060000                0.000000
# 3                     -0.060000                0.000000
# 4                     -0.060000                0.000000
# 5                     -0.060000                0.000000
# ...                         ...                     ...
# 121798                -0.275556                4.601889
# 121799                -0.300000                4.527111
# 121800                -0.312766                4.436355
# 121801                -0.322917                4.346910
# 121802                -0.344898                4.280025
#
#         rotationRate.gamma.min  rotationRate.gamma.max  \
# 1                        -0.06                   -0.06
# 2                        -0.06                   -0.06
# 3                        -0.06                   -0.06
# 4                        -0.06                   -0.06
# 5                        -0.06                   -0.06
# ...                        ...                     ...
# 121798                   -3.80                    5.20
# 121799                   -3.80                    5.20
# 121800                   -3.80                    5.20
# 121801                   -3.80                    5.20
# 121802                   -3.80                    5.20
#
#         rotationRate.gamma.median
# 1                           -0.06
# 2                           -0.06
# 3                           -0.06
# 4                           -0.06
# 5                           -0.06
# ...                           ...
# 121798                      -0.80
# 121799                      -0.85
# 121800                      -0.90
# 121801                      -0.85
# 121802                      -0.90
#
# [121722 rows x 49 columns]

# %%
# Plot a sample of the data using seaborn pairplot
sampled_data=windowed_data_copy.sample(1000)
sns.pairplot(sampled_data, hue='activity')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Plot a sample of the data using seaborn pairplot
# ----> 2 sampled_data=windowed_data_copy.sample(1000)
#       3 sns.pairplot(sampled_data, hue='activity')
#       4 plt.show()
#
# NameError: name 'windowed_data_copy' is not defined

# %%
# Define the classifier
clf = RandomForestClassifier(random_state=0)

# Prepare features and labels for cross-validation and RFECV
X = sampled_data.drop(['activity','participantId'], axis=1) # Features
y = sampled_data['activity'].ravel() # Labels
groups = sampled_data['participantId'] # Group identifiers

# Perform cross-validation using Leave-One-Group-Out
scores=cross_val_score(clf, X, y, cv=LeaveOneGroupOut(), groups=groups, scoring="f1_macro")
scores.mean()
# Out:
# /tmp/ipykernel_3247/2561959201.py:6: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y = sampled_data['activity'].ravel() # Labels
# 0.5785533384652329

# %%
# Perform Recursive Feature Elimination with Cross-Validation (RFECV)
rfecv = RFECV(estimator=clf, step=1, scoring='f1_macro')
rfecv = rfecv.fit(X, y)

# %%
# Plot RFECV results
cv_results = pd.DataFrame(rfecv.cv_results_)
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Mean test accuracy")
plt.errorbar(
    x=cv_results.index,
    y=cv_results["mean_test_score"],
    yerr=cv_results["std_test_score"],
)
plt.title("Recursive Feature Elimination")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Plot RFECV results
# ----> 2 cv_results = pd.DataFrame(rfecv.cv_results_)
#       3 plt.figure()
#       4 plt.xlabel("Number of features selected")
#
# NameError: name 'pd' is not defined

# %%
windowed_data_copy
# Out:
#        participantId  activity  browser_Chrome  browser_Firefox  \
# 1              10280       2.0             0.0              1.0
# 2              10280       2.0             0.0              1.0
# 3              10280       2.0             0.0              1.0
# 4              10280       2.0             0.0              1.0
# 5              10280       2.0             0.0              1.0
# ...              ...       ...             ...              ...
# 121798         uksco       2.0             1.0              0.0
# 121799         uksco       2.0             1.0              0.0
# 121800         uksco       2.0             1.0              0.0
# 121801         uksco       2.0             1.0              0.0
# 121802         uksco       2.0             1.0              0.0
#
#         acceleration.x.mean  acceleration.x.var  acceleration.x.min  \
# 1                  0.000000            0.000000                 0.0
# 2                  0.000000            0.000000                 0.0
# 3                  0.000000            0.000000                 0.0
# 4                  0.000000            0.000000                 0.0
# 5                  0.000000            0.000000                 0.0
# ...                     ...                 ...                 ...
# 121798            -0.020000            0.008909                -0.2
# 121799            -0.017391            0.009024                -0.2
# 121800            -0.017021            0.008834                -0.2
# 121801            -0.016667            0.008652                -0.2
# 121802            -0.016327            0.008478                -0.2
#
#         acceleration.x.max  acceleration.x.median  acceleration.y.mean  ...  \
# 1                      0.0                    0.0             0.020000  ...
# 2                      0.0                    0.0             0.020000  ...
# 3                      0.0                    0.0             0.020000  ...
# 4                      0.0                    0.0             0.020000  ...
# 5                      0.0                    0.0             0.020000  ...
# ...                    ...                    ...                  ...  ...
# 121798                 0.1                    0.0            -0.006667  ...
# 121799                 0.1                    0.0            -0.006522  ...
# 121800                 0.1                    0.0            -0.006383  ...
# 121801                 0.1                    0.0            -0.006250  ...
# 121802                 0.1                    0.0            -0.006122  ...
#
#         rotationRate.beta.mean  rotationRate.beta.var  rotationRate.beta.min  \
# 1                    -0.030000               0.000000                  -0.03
# 2                    -0.030000               0.000000                  -0.03
# 3                    -0.030000               0.000000                  -0.03
# 4                    -0.030000               0.000000                  -0.03
# 5                    -0.030000               0.000000                  -0.03
# ...                        ...                    ...                    ...
# 121798                0.900000              15.907273                  -9.80
# 121799                0.908696              15.557256                  -9.80
# 121800                0.861702              15.322850                  -9.80
# 121801                0.804167              15.155727                  -9.80
# 121802                0.779592              14.869575                  -9.80
#
#         rotationRate.beta.max  rotationRate.beta.median  \
# 1                       -0.03                     -0.03
# 2                       -0.03                     -0.03
# 3                       -0.03                     -0.03
# 4                       -0.03                     -0.03
# 5                       -0.03                     -0.03
# ...                       ...                       ...
# 121798                   9.00                      1.10
# 121799                   9.00                      1.10
# 121800                   9.00                      1.10
# 121801                   9.00                      0.95
# 121802                   9.00                      0.80
#
#         rotationRate.gamma.mean  rotationRate.gamma.var  \
# 1                     -0.060000                0.000000
# 2                     -0.060000                0.000000
# 3                     -0.060000                0.000000
# 4                     -0.060000                0.000000
# 5                     -0.060000                0.000000
# ...                         ...                     ...
# 121798                -0.275556                4.601889
# 121799                -0.300000                4.527111
# 121800                -0.312766                4.436355
# 121801                -0.322917                4.346910
# 121802                -0.344898                4.280025
#
#         rotationRate.gamma.min  rotationRate.gamma.max  \
# 1                        -0.06                   -0.06
# 2                        -0.06                   -0.06
# 3                        -0.06                   -0.06
# 4                        -0.06                   -0.06
# 5                        -0.06                   -0.06
# ...                        ...                     ...
# 121798                   -3.80                    5.20
# 121799                   -3.80                    5.20
# 121800                   -3.80                    5.20
# 121801                   -3.80                    5.20
# 121802                   -3.80                    5.20
#
#         rotationRate.gamma.median
# 1                           -0.06
# 2                           -0.06
# 3                           -0.06
# 4                           -0.06
# 5                           -0.06
# ...                           ...
# 121798                      -0.80
# 121799                      -0.85
# 121800                      -0.90
# 121801                      -0.85
# 121802                      -0.90
#
# [121722 rows x 49 columns]

# %%
# Prepare the final result dataframe with selected features
result_data=pd.concat([windowed_data_copy.participantId,pd.DataFrame(labels[windowed_data_copy.activity.astype(int)],columns=["activity"]),windowed_data_copy[rfecv.get_feature_names_out(X.columns)]],axis=1).dropna()
df6
# Out:
#        participantId activity  acceleration.y.var  acceleration.y.min  \
# 1              10280  sitting            0.000000                0.02
# 2              10280  sitting            0.000000                0.02
# 3              10280  sitting            0.000000                0.02
# 4              10280  sitting            0.000000                0.02
# 5              10280  sitting            0.000000                0.02
# ...              ...      ...                 ...                 ...
# 121717         uksco  sitting            9.122666               -2.70
# 121718         uksco  sitting            8.215636               -2.70
# 121719         uksco  sitting            7.480909               -2.70
# 121720         uksco  sitting            6.997692               -2.70
# 121721         uksco  sitting            6.463736               -2.70
#
#         acceleration.z.var  accelerationIncludingGravity.x.mean  \
# 1                 0.000000                             0.030000
# 2                 0.000000                             0.030000
# 3                 0.000000                             0.030000
# 4                 0.000000                             0.030000
# 5                 0.000000                             0.030000
# ...                    ...                                  ...
# 121717          156.284988                            17.680000
# 121718          140.694899                            17.263637
# 121719          129.451809                            16.675000
# 121720          122.819735                            15.984616
# 121721          122.307464                            15.421429
#
#         accelerationIncludingGravity.x.median  \
# 1                                    0.030000
# 2                                    0.030000
# 3                                    0.030000
# 4                                    0.030000
# 5                                    0.030000
# ...                                       ...
# 121717                              18.900001
# 121718                              18.600000
# 121719                              17.150000
# 121720                              15.700000
# 121721                              14.850000
#
#         accelerationIncludingGravity.y.mean  \
# 1                                  0.030000
# 2                                  0.030000
# 3                                  0.030000
# 4                                  0.030000
# 5                                  0.030000
# ...                                     ...
# 121717                            -1.930000
# 121718                            -1.863636
# 121719                            -1.908333
# 121720                            -2.061538
# 121721                            -2.121429
#
#         accelerationIncludingGravity.y.var  \
# 1                                 0.000000
# 2                                 0.000000
# 3                                 0.000000
# 4                                 0.000000
# 5                                 0.000000
# ...                                    ...
# 121717                            3.013445
# 121718                            2.760546
# 121719                            2.533561
# 121720                            2.627564
# 121721                            2.475659
#
#         accelerationIncludingGravity.y.min  ...  \
# 1                                     0.03  ...
# 2                                     0.03  ...
# 3                                     0.03  ...
# 4                                     0.03  ...
# 5                                     0.03  ...
# ...                                    ...  ...
# 121717                               -3.30  ...
# 121718                               -3.30  ...
# 121719                               -3.30  ...
# 121720                               -3.90  ...
# 121721                               -3.90  ...
#
#         accelerationIncludingGravity.y.median  \
# 1                                        0.03
# 2                                        0.03
# 3                                        0.03
# 4                                        0.03
# 5                                        0.03
# ...                                       ...
# 121717                                  -2.30
# 121718                                  -2.30
# 121719                                  -2.30
# 121720                                  -2.30
# 121721                                  -2.30
#
#         accelerationIncludingGravity.z.var  \
# 1                                 0.000000
# 2                                 0.000000
# 3                                 0.000025
# 4                                 0.000030
# 5                                 0.000030
# ...                                    ...
# 121717                           99.938769
# 121718                           94.776174
# 121719                           87.902644
# 121720                           85.010762
# 121721                           87.284389
#
#         accelerationIncludingGravity.z.min  \
# 1                                 9.840000
# 2                                 9.840000
# 3                                 9.840000
# 4                                 9.840000
# 5                                 9.840000
# ...                                    ...
# 121717                          -32.099998
# 121718                          -32.099998
# 121719                          -32.099998
# 121720                          -32.099998
# 121721                          -32.099998
#
#         accelerationIncludingGravity.z.max  \
# 1                                     9.84
# 2                                     9.84
# 3                                     9.85
# 4                                     9.85
# 5                                     9.85
# ...                                    ...
# 121717                                1.50
# 121718                                1.50
# 121719                                1.50
# 121720                                2.60
# 121721                                6.70
#
#         accelerationIncludingGravity.z.median  rotationRate.alpha.var  \
# 1                                       9.840                0.000000
# 2                                       9.840                0.000000
# 3                                       9.840                0.000000
# 4                                       9.840                0.000000
# 5                                       9.845                0.000000
# ...                                       ...                     ...
# 121717                                 -1.700             1655.137330
# 121718                                 -2.100            12838.261634
# 121719                                 -1.700            17064.427240
# 121720                                 -1.300            17723.949377
# 121721                                 -1.050            17159.300723
#
#         rotationRate.alpha.min  rotationRate.beta.var  rotationRate.beta.max  \
# 1                     0.000000               0.000000              -0.030000
# 2                     0.000000               0.000000              -0.030000
# 3                     0.000000               0.000000              -0.030000
# 4                     0.000000               0.000000              -0.030000
# 5                     0.000000               0.000000              -0.030000
# ...                        ...                    ...                    ...
# 121717               90.300003            8818.709404             103.500000
# 121718             -205.899994            9344.820570             103.500000
# 121719             -205.899994           13181.429436             215.300003
# 121720             -205.899994           14116.102395             215.300003
# 121721             -205.899994           13070.944087             215.300003
#
#         rotationRate.gamma.var
# 1                     0.000000
# 2                     0.000000
# 3                     0.000000
# 4                     0.000000
# 5                     0.000000
# ...                        ...
# 121717             8896.485613
# 121718             9853.118897
# 121719            10292.051910
# 121720            10373.772592
# 121721            10744.388508
#
# [121644 rows x 21 columns]

# %%
# Plot the activity distribution
result_data.activity.hist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Plot the activity distribution
# ----> 2 result_data.activity.hist()
#
# NameError: name 'result_data' is not defined

# %%
# Save the final features to a pickle file
with open("../exercises/features.pkl", "wb") as f:
    pickle.dump(result_data, f)

# %%
result_data
# Out:
#        participantId activity  acceleration.y.var  acceleration.y.min  \
# 1              10280  sitting            0.000000                0.02
# 2              10280  sitting            0.000000                0.02
# 3              10280  sitting            0.000000                0.02
# 4              10280  sitting            0.000000                0.02
# 5              10280  sitting            0.000000                0.02
# ...              ...      ...                 ...                 ...
# 121717         uksco  sitting            9.122666               -2.70
# 121718         uksco  sitting            8.215636               -2.70
# 121719         uksco  sitting            7.480909               -2.70
# 121720         uksco  sitting            6.997692               -2.70
# 121721         uksco  sitting            6.463736               -2.70
#
#         acceleration.z.var  accelerationIncludingGravity.x.mean  \
# 1                 0.000000                             0.030000
# 2                 0.000000                             0.030000
# 3                 0.000000                             0.030000
# 4                 0.000000                             0.030000
# 5                 0.000000                             0.030000
# ...                    ...                                  ...
# 121717          156.284988                            17.680000
# 121718          140.694899                            17.263637
# 121719          129.451809                            16.675000
# 121720          122.819735                            15.984616
# 121721          122.307464                            15.421429
#
#         accelerationIncludingGravity.x.median  \
# 1                                    0.030000
# 2                                    0.030000
# 3                                    0.030000
# 4                                    0.030000
# 5                                    0.030000
# ...                                       ...
# 121717                              18.900001
# 121718                              18.600000
# 121719                              17.150000
# 121720                              15.700000
# 121721                              14.850000
#
#         accelerationIncludingGravity.y.mean  \
# 1                                  0.030000
# 2                                  0.030000
# 3                                  0.030000
# 4                                  0.030000
# 5                                  0.030000
# ...                                     ...
# 121717                            -1.930000
# 121718                            -1.863636
# 121719                            -1.908333
# 121720                            -2.061538
# 121721                            -2.121429
#
#         accelerationIncludingGravity.y.var  \
# 1                                 0.000000
# 2                                 0.000000
# 3                                 0.000000
# 4                                 0.000000
# 5                                 0.000000
# ...                                    ...
# 121717                            3.013445
# 121718                            2.760546
# 121719                            2.533561
# 121720                            2.627564
# 121721                            2.475659
#
#         accelerationIncludingGravity.y.min  ...  \
# 1                                     0.03  ...
# 2                                     0.03  ...
# 3                                     0.03  ...
# 4                                     0.03  ...
# 5                                     0.03  ...
# ...                                    ...  ...
# 121717                               -3.30  ...
# 121718                               -3.30  ...
# 121719                               -3.30  ...
# 121720                               -3.90  ...
# 121721                               -3.90  ...
#
#         accelerationIncludingGravity.y.median  \
# 1                                        0.03
# 2                                        0.03
# 3                                        0.03
# 4                                        0.03
# 5                                        0.03
# ...                                       ...
# 121717                                  -2.30
# 121718                                  -2.30
# 121719                                  -2.30
# 121720                                  -2.30
# 121721                                  -2.30
#
#         accelerationIncludingGravity.z.var  \
# 1                                 0.000000
# 2                                 0.000000
# 3                                 0.000025
# 4                                 0.000030
# 5                                 0.000030
# ...                                    ...
# 121717                           99.938769
# 121718                           94.776174
# 121719                           87.902644
# 121720                           85.010762
# 121721                           87.284389
#
#         accelerationIncludingGravity.z.min  \
# 1                                 9.840000
# 2                                 9.840000
# 3                                 9.840000
# 4                                 9.840000
# 5                                 9.840000
# ...                                    ...
# 121717                          -32.099998
# 121718                          -32.099998
# 121719                          -32.099998
# 121720                          -32.099998
# 121721                          -32.099998
#
#         accelerationIncludingGravity.z.max  \
# 1                                     9.84
# 2                                     9.84
# 3                                     9.85
# 4                                     9.85
# 5                                     9.85
# ...                                    ...
# 121717                                1.50
# 121718                                1.50
# 121719                                1.50
# 121720                                2.60
# 121721                                6.70
#
#         accelerationIncludingGravity.z.median  rotationRate.alpha.var  \
# 1                                       9.840                0.000000
# 2                                       9.840                0.000000
# 3                                       9.840                0.000000
# 4                                       9.840                0.000000
# 5                                       9.845                0.000000
# ...                                       ...                     ...
# 121717                                 -1.700             1655.137330
# 121718                                 -2.100            12838.261634
# 121719                                 -1.700            17064.427240
# 121720                                 -1.300            17723.949377
# 121721                                 -1.050            17159.300723
#
#         rotationRate.alpha.min  rotationRate.beta.var  rotationRate.beta.max  \
# 1                     0.000000               0.000000              -0.030000
# 2                     0.000000               0.000000              -0.030000
# 3                     0.000000               0.000000              -0.030000
# 4                     0.000000               0.000000              -0.030000
# 5                     0.000000               0.000000              -0.030000
# ...                        ...                    ...                    ...
# 121717               90.300003            8818.709404             103.500000
# 121718             -205.899994            9344.820570             103.500000
# 121719             -205.899994           13181.429436             215.300003
# 121720             -205.899994           14116.102395             215.300003
# 121721             -205.899994           13070.944087             215.300003
#
#         rotationRate.gamma.var
# 1                     0.000000
# 2                     0.000000
# 3                     0.000000
# 4                     0.000000
# 5                     0.000000
# ...                        ...
# 121717             8896.485613
# 121718             9853.118897
# 121719            10292.051910
# 121720            10373.772592
# 121721            10744.388508
#
# [121644 rows x 21 columns]
